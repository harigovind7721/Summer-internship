# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10,5))
df = pd.read_excel("SuperStoreOrders_cleaned.xlsx")

#CUSTOMER ANALYSIS
#TOP CUSTOMERS BY REVENUE
top_customers = df.groupby('customer_name')['sales'].sum() \
                  .sort_values(ascending=False).head(20)
top_customers.plot(kind='bar')
plt.title("Top Customers by Revenue")
plt.ylabel("Revenue")
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
print("INSIGHTS:A few customers contribute large share of revenue.")
print("RECOMMENDATION:Provide loyalty programs for high-value customers.")

#CUSTOMERS WITH LOW PROFITABILITY
low_profit_customers = df.groupby('customer_name')['profit'].sum() \
                         .sort_values(ascending=False).head(20)
low_profit_customers.plot(kind='bar')
plt.title("Customers with Low Profitability")
plt.ylabel("Profit")
plt.xticks(rotation=90)
plt.show()
print("INSIGHTS:Some customers purchase frequently but generate low profit.")
print("RECOMMENDATION:Review discounts and pricing offered to these customers.")

#REPEAT PURCHASING BEHAVIOR
repeat_customers = df.groupby('customer_name')['order_id'].count() \
                     .sort_values(ascending=False).head(20)
repeat_customers.plot(kind='bar')
plt.title("Repeat Purchasing Customers")
plt.ylabel("Number of Orders")
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
print("INSIGHTS:Some customers show strong repeat purchasing behavior.")
print("RECOMMENDATION:Create customer retention programs for repeat buyers.")
# Out:
# INSIGHTS:A few customers contribute large share of revenue.
# RECOMMENDATION:Provide loyalty programs for high-value customers.
# INSIGHTS:Some customers purchase frequently but generate low profit.
# RECOMMENDATION:Review discounts and pricing offered to these customers.
# INSIGHTS:Some customers show strong repeat purchasing behavior.
# RECOMMENDATION:Create customer retention programs for repeat buyers.

# %% [markdown]
# ## Task 2: Exploratory Data Analysis (EDA)
#
# In this task, Exploratory Data Analysis (EDA) was performed on the retail sales dataset to understand sales trends, profitability, customer behavior, and product performance. Different visualizations such as bar charts, line charts, pie charts, and box plots were used to analyze category-wise sales, regional performance, time-based trends, profitable products, and customer purchasing behavior.
#
# The analysis helped identify high-performing products and regions, seasonal sales patterns, profitable customer segments, and loss-making products. These insights can help the company improve business decisions, increase profitability, optimize discounts, and enhance customer retention strategies.
#
# A. Sales and Profit Analysis
#
# * Highest sales category-Technology
#
# * Highest profit category-Technology
#
# * Highest sales sub-category-Phones
#
# * Highest profit sub-category-Copiers
#
# * Highest sales region-Central
#
# * Highest profit region-North
#
# * Highest sales state-England
#
# * Highest profit segment-Consumer
#
# B. Time-Based Analysis
#
# * Highest sales month	-November
#
# * Highest profit year-2014
#
# * Peak sales season-Holiday season
#
# C. Product Performance
#
# * Top profitable products-Copiers
#
# * Highest loss products-Tables
#
# D. Customer Analysis
#
# * Top revenue customers-High-value customers
#
# * Low profitability customers-Discount customers
#
# * Repeat purchasing behavior-Loyal customers
#
#
# Analysis                  -                              Recommendation
# * Technology category has high sales and profit  - Increase marketing and stock for technology
#                                                     products
# * Phones sub-category performs well      - Promote phone-related offers and bundles
# * Copiers generate high profit     - Focus more on high-margin copier products
# * Tables create losses    -   Reduce discounts or discontinue low-performing tables
#
# * Some regions have low profit         - Improve pricing and reduce excessive discounts in weak                                             regions
#
# * High sales states perform better      -   Expand business operations in top-performing states
# * Consumer segment gives high profit   -    Target consumer customers with loyalty programs
# * Sales peak during holiday season    -   Increase inventory and advertising during festive                                                 months
# * High discounts reduce profit   -  Apply controlled discount strategies
# * Top customers generate high revenue   -  Provide special offers and retention programs for                                                loyal customers
# * Low-profit customers affect margins  -  Avoid heavy discounts for low-profit customers
# * Repeat customers are valuable    -    Introduce membership and reward programs
# * Seasonal sales fluctuate        - Plan seasonal marketing campaigns
# * Loss-making products reduce profit   -    Analyze product pricing and supplier costs
